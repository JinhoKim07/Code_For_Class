# %%
# To support both python 2 and python 3
from __future__ import division, print_function, unicode_literals

# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

# %%
import pandas as pd # Data-Frame Handling

Data = pd.read_csv("./Data/train.csv")
Data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
# Find the Base-Truth 

base_truth = Data['Survived'].mean()
other_truth = 1-base_truth
print (base_truth, other_truth)

ground_truth = max(base_truth, other_truth)
print(ground_truth)
# Out:
# 0.383838383838 0.616161616162
# 0.616161616162

# %%
Corr_mat = Data.corr()
Corr_mat
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
Corr_mat["Survived"].sort_values(ascending=False)
# Out:
# Survived       1.000000
# Fare           0.257307
# Parch          0.081629
# PassengerId   -0.005007
# SibSp         -0.035322
# Age           -0.077221
# Pclass        -0.338481
# Name: Survived, dtype: float64

# %%
## 성별 only

Class_Sex = Data.groupby('Sex').mean()
Class_Sex
Class_Sex['Survived'].plot.bar()

# %%
Data.groupby('Pclass').mean()

# See the Correlation Matrix "pclass" vs "fare"
# Why Correlation between "pclass" and "fare" has (large) negative value?
# Out:
#         PassengerId  Survived        Age     SibSp     Parch       Fare
# Pclass
# 1        461.597222  0.629630  38.233441  0.416667  0.356481  84.154687
# 2        445.956522  0.472826  29.877630  0.402174  0.380435  20.662183
# 3        439.154786  0.242363  25.140620  0.615071  0.393075  13.675550

# %%
Class_sex_pclass= Data.groupby(['Pclass','Sex']).mean()
Class_sex_pclass
# Out:
#                PassengerId  Survived        Age     SibSp     Parch  \
# Pclass Sex
# 1      female   469.212766  0.968085  34.611765  0.553191  0.457447
#        male     455.729508  0.368852  41.281386  0.311475  0.278689
# 2      female   443.105263  0.921053  28.722973  0.486842  0.605263
#        male     447.962963  0.157407  30.740707  0.342593  0.222222
# 3      female   399.729167  0.500000  21.750000  0.895833  0.798611
#        male     455.515850  0.135447  26.507589  0.498559  0.224784
#
#                      Fare
# Pclass Sex
# 1      female  106.125798
#        male     67.226127
# 2      female   21.970121
#        male     19.741782
# 3      female   16.118810
#        male     12.661633

# %%
Class_sex_pclass['Survived'].plot.bar()

# %%
Group_by_age = pd.cut(Data["Age"], np.arange(0,90,10))
Class_age = Data.groupby(Group_by_age).mean()
#Class_age
Class_age['Survived'].plot.bar()

# %%
Class_Age_Pclass = Data.groupby(["Sex",Group_by_age]).mean()
Class_Age_Pclass['Survived'].plot.bar()

# %%
Data.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
## Cabin Preprocessing -> Cabin_bool = Null = 0, Other = 1 

Data.loc[Data["Cabin"].str.contains('.',regex=True,na=False),"Cabin_Bin"] = 1
Data["Cabin_Bin"].fillna(0, inplace=True)

Data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Cabin_Bin
# 0      0         A/5 21171   7.2500   NaN        S        0.0
# 1      0          PC 17599  71.2833   C85        C        1.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S        0.0
# 3      0            113803  53.1000  C123        S        1.0
# 4      0            373450   8.0500   NaN        S        0.0

# %%
Data = Data.drop(["Cabin"],axis=1)
Data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked  Cabin_Bin
# 0      0         A/5 21171   7.2500        S        0.0
# 1      0          PC 17599  71.2833        C        1.0
# 2      0  STON/O2. 3101282   7.9250        S        0.0
# 3      0            113803  53.1000        S        1.0
# 4      0            373450   8.0500        S        0.0

# %%
Data = Data.dropna()

# %%
Data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked  Cabin_Bin
# 0      0         A/5 21171   7.2500        S        0.0
# 1      0          PC 17599  71.2833        C        1.0
# 2      0  STON/O2. 3101282   7.9250        S        0.0
# 3      0            113803  53.1000        S        1.0
# 4      0            373450   8.0500        S        0.0

# %%
## Parch > 0 and Age < 10

Data.loc[(Data["Parch"]>0) & (Data["Age"]<10),"Child_with_Parent"] = 1
Data["Child_with_Parent"].fillna(0, inplace=True)
#Data.head()

Data["Survived"].loc[Data["Child_with_Parent"] == 1].sum() / len(Data["Survived"].loc[Data["Child_with_Parent"] == 1])
# Out:
# 0.53886010362694303

# %%
from sklearn import preprocessing

processed_df = Data.copy()
le = preprocessing.LabelEncoder()
processed_df.Sex = le.fit_transform(processed_df.Sex)
processed_df.Embarked = le.fit_transform(processed_df.Embarked)
processed_df.Cabin_Bin = le.fit_transform(processed_df.Cabin_Bin)
processed_df.Child_with_Parent = le.fit_transform(processed_df.Child_with_Parent)

processed_df = processed_df.drop(['Name','Ticket','PassengerId'],axis=1)

# %%
processed_df.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  Cabin_Bin  \
# 0         0       3    1  22.0      1      0   7.2500         2          0
# 1         1       1    0  38.0      1      0  71.2833         0          1
# 2         1       3    0  26.0      0      0   7.9250         2          0
# 3         1       1    0  35.0      1      0  53.1000         2          1
# 4         0       3    1  35.0      0      0   8.0500         2          0
#
#    Child_with_Parent
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0

# %%
Corr_mat = processed_df.corr()
Corr_mat
#print(Corr_mat["Survived"].sort_values(ascending=False))
# Out:
#                    Survived    Pclass       Sex       Age     SibSp     Parch  \
# Survived           1.000000 -0.356462 -0.536762 -0.082446 -0.015523  0.095265
# Pclass            -0.356462  1.000000  0.150826 -0.365902  0.065187  0.023666
# Sex               -0.536762  0.150826  1.000000  0.099037 -0.106296 -0.249543
# Age               -0.082446 -0.365902  0.099037  1.000000 -0.307351 -0.187896
# SibSp             -0.015523  0.065187 -0.106296 -0.307351  1.000000  0.383338
# Parch              0.095265  0.023666 -0.249543 -0.187896  0.383338  1.000000
# Fare               0.266100 -0.552893 -0.182457  0.093143  0.139860  0.206624
# Embarked          -0.181979  0.244145  0.109639 -0.032565  0.033064  0.011803
# Cabin_Bin          0.320733 -0.737721 -0.143177  0.244981 -0.031345  0.029509
# Child_with_Parent  0.112312  0.142081 -0.073898 -0.559824  0.517434  0.401871
#
#                        Fare  Embarked  Cabin_Bin  Child_with_Parent
# Survived           0.266100 -0.181979   0.320733           0.112312
# Pclass            -0.552893  0.244145  -0.737721           0.142081
# Sex               -0.182457  0.109639  -0.143177          -0.073898
# Age                0.093143 -0.032565   0.244981          -0.559824
# SibSp              0.139860  0.033064  -0.031345           0.517434
# Parch              0.206624  0.011803   0.029509           0.401871
# Fare               1.000000 -0.283510   0.490477          -0.005361
# Embarked          -0.283510  1.000000  -0.239361           0.038263
# Cabin_Bin          0.490477 -0.239361   1.000000          -0.064677
# Child_with_Parent -0.005361  0.038263  -0.064677           1.000000

# %%
from sklearn import cross_validation

X_drop_cabin = processed_df.drop(['Survived','Cabin_Bin'],axis=1).values
X = processed_df.drop(['Survived'],axis=1).values
y = processed_df['Survived'].values

X_train, X_test, y_train, y_test = cross_validation.train_test_split(X,y,test_size=0.2)

# or Use the gridsearch

# %%
from sklearn.manifold import TSNE
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D

pca_tsne = Pipeline([
    
    ("pca", PCA(n_components=2, random_state=42)),
    ("tsne", TSNE(n_components=2, random_state=42)),
])
X_reduced = pca_tsne.fit_transform(X_train)

plt.figure(figsize=(13,10))
plt.scatter(X_reduced[:,0], X_reduced[:,1], c=y_train)

plt.axis("off")
plt.show()

# %%
#print ("test ratio",sum(y_test)/len(y_test))
#print ("train ratio",sum(y_train)/len(y_train))
print ("test ratio", y_test.mean())
print ("test ratio", y_train.mean())
# Out:
# test ratio 0.398601398601
# test ratio 0.405975395431

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

logit_reg = LogisticRegression()
logit_reg
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
from sklearn.model_selection import GridSearchCV

param_grid = [
    {'penalty': ["l1","l2"], 'C':[0.5,1.0,2.0,999.]} 
    # Inverse of regularization Strength -> 1/C
    ]

logit_reg = LogisticRegression()
grid_search = GridSearchCV(logit_reg, param_grid, cv=5,
                          scoring="accuracy")

grid_search.fit(X,y)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid=[{'penalty': ['l1', 'l2'], 'C': [0.5, 1.0, 2.0, 999.0]}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring='accuracy', verbose=0)

# %%
cvres = grid_search.cv_results_
#cvres

for acc, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(acc, params)
    
print (grid_search.best_params_)
print (grid_search.best_score_)
# Out:
# 0.786516853933 {'C': 0.5, 'penalty': 'l1'}
# 0.77808988764 {'C': 0.5, 'penalty': 'l2'}
# 0.790730337079 {'C': 1.0, 'penalty': 'l1'}
# 0.786516853933 {'C': 1.0, 'penalty': 'l2'}
# 0.790730337079 {'C': 2.0, 'penalty': 'l1'}
# 0.786516853933 {'C': 2.0, 'penalty': 'l2'}
# 0.787921348315 {'C': 999.0, 'penalty': 'l1'}
# 0.787921348315 {'C': 999.0, 'penalty': 'l2'}
# {'C': 1.0, 'penalty': 'l1'}
# 0.790730337079

# %% [markdown]
# ## Support Vector Machine

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC

svm_clf_pipe = Pipeline([
            ("scaler", StandardScaler()),
            ("svm_clf", SVC())
])

param_grid = [
        {'svm_clf__kernel': ['linear'], 'svm_clf__C': [10., 100., 1000.,10000.]},
        {'svm_clf__kernel': ['rbf'], 'svm_clf__C': [1.0,10.,100.,1000.0],
         'svm_clf__gamma': [0.01,0.1,1.0,]},
    ]

grid_search = GridSearchCV(svm_clf_pipe, param_grid, cv=5,
                          scoring="accuracy")

grid_search.fit(X,y)

cvres = grid_search.cv_results_

for acc, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(acc, params)
# Out:
# 0.792134831461 {'svm_clf__C': 10.0, 'svm_clf__kernel': 'linear'}
# 0.792134831461 {'svm_clf__C': 100.0, 'svm_clf__kernel': 'linear'}
# 0.792134831461 {'svm_clf__C': 1000.0, 'svm_clf__kernel': 'linear'}
# 0.792134831461 {'svm_clf__C': 10000.0, 'svm_clf__kernel': 'linear'}
# 0.787921348315 {'svm_clf__C': 1.0, 'svm_clf__gamma': 0.01, 'svm_clf__kernel': 'rbf'}
# 0.827247191011 {'svm_clf__C': 1.0, 'svm_clf__gamma': 0.1, 'svm_clf__kernel': 'rbf'}
# 0.75702247191 {'svm_clf__C': 1.0, 'svm_clf__gamma': 1.0, 'svm_clf__kernel': 'rbf'}
# 0.820224719101 {'svm_clf__C': 10.0, 'svm_clf__gamma': 0.01, 'svm_clf__kernel': 'rbf'}
# 0.794943820225 {'svm_clf__C': 10.0, 'svm_clf__gamma': 0.1, 'svm_clf__kernel': 'rbf'}
# 0.75702247191 {'svm_clf__C': 10.0, 'svm_clf__gamma': 1.0, 'svm_clf__kernel': 'rbf'}
# 0.824438202247 {'svm_clf__C': 100.0, 'svm_clf__gamma': 0.01, 'svm_clf__kernel': 'rbf'}
# 0.766853932584 {'svm_clf__C': 100.0, 'svm_clf__gamma': 0.1, 'svm_clf__kernel': 'rbf'}
# 0.744382022472 {'svm_clf__C': 100.0, 'svm_clf__gamma': 1.0, 'svm_clf__kernel': 'rbf'}
# 0.799157303371 {'svm_clf__C': 1000.0, 'svm_clf__gamma': 0.01, 'svm_clf__kernel': 'rbf'}
# 0.747191011236 {'svm_clf__C': 1000.0, 'svm_clf__gamma': 0.1, 'svm_clf__kernel': 'rbf'}
# 0.727528089888 {'svm_clf__C': 1000.0, 'svm_clf__gamma': 1.0, 'svm_clf__kernel': 'rbf'}

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

clf_dt = DecisionTreeClassifier()
clf_dt
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

dt_clf_pipe = Pipeline([
            ("scaler", StandardScaler()),
            ("tf_clf", clf_dt),
])

param_grid = [
        {'tf_clf__criterion': ['gini'], 'tf_clf__max_depth' : [2,3,4,5]},
        {'tf_clf__criterion': ['entropy'], 'tf_clf__max_depth' : [2,3,4,5]},
    ]

grid_search = GridSearchCV(dt_clf_pipe, param_grid, cv=5,
                          scoring="accuracy")

grid_search.fit(X,y)

cvres = grid_search.cv_results_

for acc, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(acc, params)
# Out:
# 0.790730337079 {'tf_clf__criterion': 'gini', 'tf_clf__max_depth': 2}
# 0.800561797753 {'tf_clf__criterion': 'gini', 'tf_clf__max_depth': 3}
# 0.810393258427 {'tf_clf__criterion': 'gini', 'tf_clf__max_depth': 4}
# 0.790730337079 {'tf_clf__criterion': 'gini', 'tf_clf__max_depth': 5}
# 0.790730337079 {'tf_clf__criterion': 'entropy', 'tf_clf__max_depth': 2}
# 0.797752808989 {'tf_clf__criterion': 'entropy', 'tf_clf__max_depth': 3}
# 0.792134831461 {'tf_clf__criterion': 'entropy', 'tf_clf__max_depth': 4}
# 0.789325842697 {'tf_clf__criterion': 'entropy', 'tf_clf__max_depth': 5}

# %%
from sklearn.ensemble import RandomForestClassifier


clf_rf = RandomForestClassifier()
clf_rf
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

rf_clf_pipe = Pipeline([
            #("scaler", StandardScaler()),
            ("rf_clf", clf_rf),
])

param_grid = [
        {'rf_clf__n_estimators': [10,50,100,500], 
         'rf_clf__criterion': ["gini","entropy"], 
         'rf_clf__min_samples_split': [2,3,4,5]}
    ]

grid_search = GridSearchCV(rf_clf_pipe, param_grid, cv=5,
                          scoring="accuracy")

grid_search.fit(X,y)

cvres = grid_search.cv_results_

for acc, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(acc, params)
    
print (grid_search.best_params_)
print (grid_search.best_score_)
# Out:
# 0.793539325843 {'rf_clf__criterion': 'gini', 'rf_clf__min_samples_split': 2, 'rf_clf__n_estimators': 10}
# 0.792134831461 {'rf_clf__criterion': 'gini', 'rf_clf__min_samples_split': 2, 'rf_clf__n_estimators': 50}
# 0.790730337079 {'rf_clf__criterion': 'gini', 'rf_clf__min_samples_split': 2, 'rf_clf__n_estimators': 100}
# 0.789325842697 {'rf_clf__criterion': 'gini', 'rf_clf__min_samples_split': 2, 'rf_clf__n_estimators': 500}
# 0.796348314607 {'rf_clf__criterion': 'gini', 'rf_clf__min_samples_split': 3, 'rf_clf__n_estimators': 10}
# 0.793539325843 {'rf_clf__criterion': 'gini', 'rf_clf__min_samples_split': 3, 'rf_clf__n_estimators': 50}
# 0.780898876404 {'rf_clf__criterion': 'gini', 'rf_clf__min_samples_split': 3, 'rf_clf__n_estimators': 100}
# 0.786516853933 {'rf_clf__criterion': 'gini', 'rf_clf__min_samples_split': 3, 'rf_clf__n_estimators': 500}
# 0.787921348315 {'rf_clf__criterion': 'gini', 'rf_clf__min_samples_split': 4, 'rf_clf__n_estimators': 10}
# 0.797752808989 {'rf_clf__criterion': 'gini', 'rf_clf__min_samples_split': 4, 'rf_clf__n_estimators': 50}
# 0.794943820225 {'rf_clf__criterion': 'gini', 'rf_clf__min_samples_split': 4, 'rf_clf__n_estimators': 100}
# 0.794943820225 {'rf_clf__criterion': 'gini', 'rf_clf__min_samples_split': 4, 'rf_clf__n_estimators': 500}
# 0.801966292135 {'rf_clf__criterion': 'gini', 'rf_clf__min_samples_split': 5, 'rf_clf__n_estimators': 10}
# 0.796348314607 {'rf_clf__criterion': 'gini', 'rf_clf__min_samples_split': 5, 'rf_clf__n_estimators': 50}
# 0.801966292135 {'rf_clf__criterion': 'gini', 'rf_clf__min_samples_split': 5, 'rf_clf__n_estimators': 100}
# 0.804775280899 {'rf_clf__criterion': 'gini', 'rf_clf__min_samples_split': 5, 'rf_clf__n_estimators': 500}
# 0.789325842697 {'rf_clf__criterion': 'entropy', 'rf_clf__min_samples_split': 2, 'rf_clf__n_estimators': 10}
# 0.783707865169 {'rf_clf__criterion': 'entropy', 'rf_clf__min_samples_split': 2, 'rf_clf__n_estimators': 50}
# 0.793539325843 {'rf_clf__criterion': 'entropy', 'rf_clf__min_samples_split': 2, 'rf_clf__n_estimators': 100}
# 0.783707865169 {'rf_clf__criterion': 'entropy', 'rf_clf__min_samples_split': 2, 'rf_clf__n_estimators': 500}
# 0.785112359551 {'rf_clf__criterion': 'entropy', 'rf_clf__min_samples_split': 3, 'rf_clf__n_estimators': 10}
# 0.801966292135 {'rf_clf__criterion': 'entropy', 'rf_clf__min_samples_split': 3, 'rf_clf__n_estimators': 50}
# 0.796348314607 {'rf_clf__criterion': 'entropy', 'rf_clf__min_samples_split': 3, 'rf_clf__n_estimators': 100}
# 0.792134831461 {'rf_clf__criterion': 'entropy', 'rf_clf__min_samples_split': 3, 'rf_clf__n_estimators': 500}
# 0.787921348315 {'rf_clf__criterion': 'entropy', 'rf_clf__min_samples_split': 4, 'rf_clf__n_estimators': 10}
# 0.796348314607 {'rf_clf__criterion': 'entropy', 'rf_clf__min_samples_split': 4, 'rf_clf__n_estimators': 50}
# 0.796348314607 {'rf_clf__criterion': 'entropy', 'rf_clf__min_samples_split': 4, 'rf_clf__n_estimators': 100}
# 0.793539325843 {'rf_clf__criterion': 'entropy', 'rf_clf__min_samples_split': 4, 'rf_clf__n_estimators': 500}
# 0.796348314607 {'rf_clf__criterion': 'entropy', 'rf_clf__min_samples_split': 5, 'rf_clf__n_estimators': 10}
# 0.806179775281 {'rf_clf__criterion': 'entropy', 'rf_clf__min_samples_split': 5, 'rf_clf__n_estimators': 50}
# 0.796348314607 {'rf_clf__criterion': 'entropy', 'rf_clf__min_samples_split': 5, 'rf_clf__n_estimators': 100}
# 0.797752808989 {'rf_clf__criterion': 'entropy', 'rf_clf__min_samples_split': 5, 'rf_clf__n_estimators': 500}
# {'rf_clf__criterion': 'entropy', 'rf_clf__min_samples_split': 5, 'rf_clf__n_estimators': 50}
# 0.806179775281

# %%
from sklearn.ensemble import GradientBoostingClassifier
clf_gb = GradientBoostingClassifier()
clf_gb
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_split=1e-07, min_samples_leaf=1,
#               min_samples_split=2, min_weight_fraction_leaf=0.0,
#               n_estimators=100, presort='auto', random_state=None,
#               subsample=1.0, verbose=0, warm_start=False)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

gb_clf_pipe = Pipeline([
            #("scaler", StandardScaler()),
            ("gb_clf", clf_gb),
])

param_grid = [
        {'gb_clf__n_estimators': [10,50,100,500]},
    ]

grid_search = GridSearchCV(gb_clf_pipe, param_grid, cv=5,
                          scoring="accuracy")

grid_search.fit(X,y)

cvres = grid_search.cv_results_

for acc, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(acc, params)

print (grid_search.best_params_)
print (grid_search.best_score_)
# Out:
# 0.800561797753 {'gb_clf__n_estimators': 10}
# 0.811797752809 {'gb_clf__n_estimators': 50}
# 0.817415730337 {'gb_clf__n_estimators': 100}
# 0.800561797753 {'gb_clf__n_estimators': 500}
# {'gb_clf__n_estimators': 100}
# 0.817415730337

# %%
from sklearn.ensemble import VotingClassifier

eclf = VotingClassifier([('dt', clf_dt), ('rf', clf_rf), ('gb', clf_gb)])
test_classifier(eclf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-173-79c698d4cf72> in <module>()
#       2
#       3 eclf = VotingClassifier([('dt', clf_dt), ('rf', clf_rf), ('gb', clf_gb)])
# ----> 4 test_classifier(eclf)
#
# NameError: name 'test_classifier' is not defined

# %% [markdown]
# ## XGBoosting

# %%
from xgboost import XGBClassifier
from xgboost import plot_importance

# %%
xg_model = XGBClassifier(booster='gbtree',seed = 42)
xg_model.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=42, silent=True,
#        subsample=1)

# %%
test_classifier(xg_model)
# Out:
# Accuracy: 0.8287 (+/- 0.03)

# %%
plot_importance(xg_model)
plt.show()

# %%
T_Data = pd.read_csv("./Data/test.csv")
T_Data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
T_Data.loc[T_Data["Cabin"].str.contains('.',regex=True,na=False),"Cabin_Bin"] = 1
T_Data["Cabin_Bin"].fillna(0, inplace=True)
T_Data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Cabin_Bin
# 0  34.5      0      0   330911   7.8292   NaN        Q        0.0
# 1  47.0      1      0   363272   7.0000   NaN        S        0.0
# 2  62.0      0      0   240276   9.6875   NaN        Q        0.0
# 3  27.0      0      0   315154   8.6625   NaN        S        0.0
# 4  22.0      1      1  3101298  12.2875   NaN        S        0.0

# %%
from sklearn import preprocessing

processed_df = T_Data.copy()
le = preprocessing.LabelEncoder()
processed_df.Sex = le.fit_transform(processed_df.Sex)
processed_df.Embarked = le.fit_transform(processed_df.Embarked)

processed_df.Cabin_Bin = le.fit_transform(processed_df.Cabin_Bin)

processed_df = processed_df.drop(['Name','Ticket','PassengerId','Cabin'],axis=1)

median = processed_df["Age"].median()
processed_df["Age"].fillna(median,inplace=True)

median = processed_df["Fare"].median()
processed_df["Fare"].fillna(median,inplace=True)
processed_df.head()
# Out:
#    Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  Cabin_Bin
# 0       3    1  34.5      0      0   7.8292         1          0
# 1       3    0  47.0      1      0   7.0000         2          0
# 2       2    1  62.0      0      0   9.6875         1          0
# 3       3    1  27.0      0      0   8.6625         2          0
# 4       3    0  22.0      1      1  12.2875         2          0

# %%
processed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 8 columns):
# Pclass       418 non-null int64
# Sex          418 non-null int64
# Age          418 non-null float64
# SibSp        418 non-null int64
# Parch        418 non-null int64
# Fare         418 non-null float64
# Embarked     418 non-null int64
# Cabin_Bin    418 non-null int64
# dtypes: float64(2), int64(6)
# memory usage: 26.2 KB

# %%
X = processed_df.values
Result = xg_model.predict(X_test)
for i in range(len(Result)):
    print(str(T_Data["PassengerId"][i])+","+str(Result[i]))
# Out:
# 892,1
# 893,1
# 894,0
# 895,1
# 896,0
# 897,0
# 898,1
# 899,1
# 900,0
# 901,1
# 902,0
# 903,0
# 904,0
# 905,0
# 906,1
# 907,0
# 908,1
# 909,0
# 910,1
# 911,1
# 912,0
# 913,1
# 914,1
# 915,0
# 916,0
# 917,1
# 918,0
# 919,1
# 920,0
# 921,1
# 922,1
# 923,0
# 924,0
# 925,0
# 926,0
# 927,0
# 928,0
# 929,1
# 930,1
# 931,0
# 932,0
# 933,0
# 934,0
# 935,0
# 936,0
# 937,0
# 938,0
# 939,0
# 940,0
# 941,1
# 942,0
# 943,0
# 944,1
# 945,0
# 946,0
# 947,1
# 948,1
# 949,1
# 950,0
# 951,0
# 952,1
# 953,0
# 954,0
# 955,1
# 956,0
# 957,0
# 958,0
# 959,0
# 960,1
# 961,0
# 962,1
# 963,0
# 964,0
# 965,0
# 966,1
# 967,0
# 968,0
# 969,0
# 970,1
# 971,1
# 972,0
# 973,1
# 974,1
# 975,0
# 976,0
# 977,0
# 978,1
# 979,1
# 980,0
# 981,0
# 982,0
# 983,0
# 984,0
# 985,0
# 986,0
# 987,1
# 988,1
# 989,0
# 990,1
# 991,1
# 992,1
# 993,0
# 994,1
# 995,0
# 996,0
# 997,0
# 998,1
# 999,0
# 1000,0
# 1001,0
# 1002,0
# 1003,0
# 1004,0
# 1005,0
# 1006,0
# 1007,0
# 1008,0
# 1009,1
# 1010,1
# 1011,0
# 1012,0
# 1013,1
# 1014,1
# 1015,0
# 1016,1
# 1017,1
# 1018,0
# 1019,1
# 1020,0
# 1021,1
# 1022,1
# 1023,0
# 1024,0
# 1025,0
# 1026,0
# 1027,0
# 1028,0
# 1029,1
# 1030,0
# 1031,1
# 1032,1
# 1033,1
# 1034,0

# %%
## Deep Learning with TensorFlow 
import tensorflow as tf

# %%
#print (len(X[0]))

n_inputs = len(X_train[0])
n_hidden1 = 100
n_hidden2 = 100
n_outputs = 2

# %%
X = tf.placeholder(tf.float32, shape=(None,n_inputs), name="X")
y = tf.placeholder(tf.int64, shape=(None), name = "y")

# %%
def neuron_layer(X, n_neurons, name, activation=None):
    with tf.name_scope(name):
        n_inputs = int(X.get_shape()[1])

        #init = tf.truncated_normal((n_inputs,n_neurons),stddev=1.)
        
        # He Initalization
        #stddev = 2 / np.sqrt(n_inputs)
        
        # Xavier
        stddev = 1/np.sqrt(n_inputs)
        
        init = tf.truncated_normal((n_inputs, n_neurons), stddev=stddev)
        
        W = tf.Variable(init, name="kernel")
        b = tf.Variable(tf.zeros([n_neurons]), name="bias")
        Z = tf.matmul(X, W) + b
        
        # DropOut
        keep_prob = 0.2
        drop_out = tf.nn.dropout(Z, keep_prob)
        
        # Batch Nomalization
        #batch_mean,batch_var = tf.nn.moments(Z,[0])
        #scale = tf.Variable(tf.ones([n_neurons]))
        #beta  = tf.Variable(tf.zeros([n_neurons]))
        #Z_batch = tf.nn.batch_normalization(Z,batch_mean,batch_var,beta,scale,1e-3)
        
        if activation is not None:
            return activation(Z)
        else:
            return Z

# %%
with tf.name_scope("dnn"):
    hidden1 = neuron_layer(X, n_hidden1, name="hidden1",
                           activation=tf.nn.sigmoid)
    hidden2 = neuron_layer(hidden1, n_hidden2, name="hidden2",
                           activation=tf.nn.sigmoid)
    logits = neuron_layer(hidden2, n_outputs, name="outputs")

# %%
with tf.name_scope("loss"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y,
                                                              logits=logits)
    loss = tf.reduce_mean(xentropy, name="loss")

# %%
learning_rate = 0.01

with tf.name_scope("train"):
    #optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    optimizer = tf.train.AdamOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)

# %%
with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

# %%
init = tf.global_variables_initializer()
#saver = tf.train.Saver()
n_epochs = 100
batch_size = 50

# %%
from random import sample

def prepare_batch(X_train, y_train, batch_size):
    Batch = np.random.randint(0,len(X_train),batch_size)
    X_batch = np.stack(X_train[idx] for idx in Batch)
    y_batch = np.stack(y_train[idx] for idx in Batch)
    
    return X_batch, y_batch

# %%
with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        for iteration in range(len(X_train) // batch_size):
            X_batch, y_batch = prepare_batch(X_train, y_train, batch_size)
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        
        if (epoch % 10 ==0):
            acc_train = accuracy.eval(feed_dict={X: X_batch, y: y_batch})
            acc_test = accuracy.eval(feed_dict={X: X_test, y: y_test}) 
            print(epoch, "Train accuracy:", acc_train, "Test accuracy:", acc_test)

        #save_path = saver.save(sess, checkpoint_path)
# Out:
# 0 Train accuracy: 0.8 Test accuracy: 0.65035
# 10 Train accuracy: 0.66 Test accuracy: 0.72028
# 20 Train accuracy: 0.86 Test accuracy: 0.734266
# 30 Train accuracy: 0.74 Test accuracy: 0.79021
# 40 Train accuracy: 0.88 Test accuracy: 0.79021
# 50 Train accuracy: 0.88 Test accuracy: 0.776224
# 60 Train accuracy: 0.86 Test accuracy: 0.755245
# 70 Train accuracy: 0.9 Test accuracy: 0.79021
# 80 Train accuracy: 0.84 Test accuracy: 0.748252
# 90 Train accuracy: 0.9 Test accuracy: 0.79021
